# %% [markdown]
# <p align="center">
#   <img src="banner-proyecto-pinguino.jpg" width="800">
# </p>

# %% [markdown]
# ---
#
# # <h3><span style="background-color: #8e44ad; padding: 2px 8px; border-radius: 4px; color: white;">📅 14/04/2026</span></h3>
#
# - Leer  repositorio de Anaïs
# - Crear nuestro propio repositorio
#
# ---

# %% [markdown]
# # <h3><span style="background-color: #8e44ad; padding: 2px 8px; border-radius: 4px; color: white;">📅 15/04/2026</span></h3>
#
# - Importamos CSV
# - Necesitamos descargar la versión *Python 3.11.* - **winget install Python.Python 3.11**
# - Creamos el entorno virtual
# - Activarlo
# - Crear archivo **requirements.txt** - Desde ahí instalar las librerias
# - Conectar repositorio
# - Crear ramas en git colaborativo
# ---

# %% [markdown]
# # <h3><span style="background-color: #8e44ad; padding: 2px 8px; border-radius: 4px; color: white;">📅 16/04/2026</span></h3>
#
# - Iniciamos subiendo lo acabado
# - Nos ha dado varios problemas al descargar los cambios de remoto a local **git pull** y de local a remoto **git push**
#
# ----

# %% [markdown]
# # <h3><span style="background-color: #8e44ad; padding: 2px 8px; border-radius: 4px; color: white;">📅 17/04/2026</span></h3>
#
# - Nos hemos dado cuenta de que hemos creado mal las ramas, por lo que empezamos de 0 el repositorio y el git colaborativo
# - main
# ├── develop(dev)
# │ ├── feature/limpieza-datos
# │ ├── feature/analisis-exploratorio
# │ ├── feature/visualizaciones
# │ └── feature/modelo
#
# ## **📌 Descripción de ramas**
#
# **🟢 `main`**
# - Rama principal del proyecto
# - Código estable y final
#
# **🟡 `develop`**
# - Rama de integración
# - Aquí se juntan todas las features antes de pasar a main
#
# **🔵 `feature/*`**
# - Ramas de trabajo individual
# - Cada una contiene una funcionalidad específica:
#   - `feature/limpieza-datos` → limpieza y preparación
#   - `feature/analisis-exploratorio` → EDA
#   - `feature/visualizaciones` → gráficos
#   - `feature/modelo` → modelos de ML
#
# ## **🔄 Flujo de trabajo**
#
# 1. Crear rama desde `develop`
# 2. Trabajar en la feature
# 3. Hacer commit y push
# 4. Pull request hacia `develop`
# 5. Merge cuando esté validado

# %% [markdown]
# ### **COMMITS**
#
# **FLUJO DE TRABAJO**
#
# | Orden | Acción | Comando / Procedimiento | Notas de Seguridad |
# | :--- | :--- | :--- | :--- |
# | 1 | Preparación | git clone <url> | Solo la primera vez para bajar el proyecto. |
# | 2 | Aislamiento | python -m venv venv | Cada uno crea su entorno virtual localmente. |
# | 3 | Configuración | modificar .gitignore | Asegurarse de incluir /venv y .ipynb_checkpoints. |
# | 4 | Salto a Rama | git switch <rama_asignada> | Te mueves a la rama específica ya creada. |
# | 5 | Sincronización | git pull origin dev | Crítico: Traer los cambios de otros antes de empezar. |
# | 6 | Desarrollo | Trabajo en el Notebook |  |
# | 7 | Comitear | git add . + git commit -m "..." | Guardar cambios con Conventional Commits. |
# | 8 | Publicación | git push| Subir los cambios a la nube (GitHub/GitLab). |
# | 9 | Integración | Abrir Pull Request (PR) | Se solicita unir tu rama con la rama dev. |
# | 10 | Limpieza | git switch dev + git branch -d <rama> | Solo borrar la rama local tras confirmar el merge. Esta opción es más fácil desde remoto |
#
#
# **PROPOSITOS**
# | Tipo | Propósito | Ejemplo de uso |
# | :--- | :--- | :--- |
# | feat | Una nueva característica o funcionalidad. | feat: add database connection |
# | fix | Corrección de un error o bug. | fix: resolve null pointer exception |
# | docs | Cambios solo en la documentación. | docs: update installation instructions |
# | style | Cambios de formato (espacios, comas) que no afectan al código. | style: fix indentation in main.py |
# | refactor | Mejora del código que no arregla un bug ni añade una función. | refactor: simplify data processing loop |
# | perf | Un cambio de código que mejora el rendimiento. | perf: reduce memory usage in training |
# | test | Añadir pruebas faltantes o corregir pruebas existentes. | test: add unit tests for login module |
# | chore | Tareas de mantenimiento, dependencias o herramientas. | chore: update dependencies in package.json |
# | build | Cambios que afectan al sistema de compilación o dependencias externas. | build: upgrade gradle version |
#
# ---

# %% [markdown]
# # <h3><span style="background-color: #8e44ad; padding: 2px 8px; border-radius: 4px; color: white;">📅 20/04/2026</span></h3>
#
# ## **Indicadores Git en VS Code**
#
# Indicadores de Git en el explorador de archivos de VS Code. Te indican el estado de cada archivo respecto al repositorio Git:
#
# | Indicador | Nombre | Significado |
# |-----------|--------|-------------|
# | **M** | Modified | Modificado, pendiente de commit |
# | **U** | Untracked | Nuevo, Git no lo conoce aún |
# | **A** | Added | Añadido al staging (`git add`) |
# | **D** | Deleted | Eliminado, pendiente de commit |
# | **R** | Renamed | Renombrado respecto al repo |
# | **C** | Conflicted | Conflicto de merge sin resolver |
# | **!** | Ignored | Ignorado por `.gitignore` |
# | **S** | Submodule | Es un submódulo de Git |
# | ↑ | Push pendiente | Commits locales pendientes de subir (`git push`) |
# | ↓ | Pull pendiente | Commits remotos pendientes de bajar (`git pull`) |
# | ↑↓ | Divergencia | Cambios en ambos lados, local y remoto |
#
# ---
#
# | Color | Significado |
# |-------|-------------|
# | 🟡 Amarillo | Modificado |
# | 🟢 Verde | Nuevo o añadido |
# | 🔴 Rojo | Eliminado o en conflicto |
# | 🔘 Gris | Ignorado |

# %% [markdown]
# ## **CONFLICTO ⚠️ Resolución conflicto merge**
#
# ##### ¿Qué pasó?
#
# Al hacer `git pull`, Git detectó que dos personas habían modificado el mismo archivo (`proyecto-curie-pinguinos.ipynb`) y no pudo fusionarlos automáticamente:
#
# *CONFLICT (content): Merge conflict in proyecto-curie-pinguinos.ipynb
# Automatic merge failed; fix conflicts and then commit the result.*
#
# > No es un error como tal — es Git avisando de que necesita intervención humana.
#
#
# ##### ¿Cómo se resolvió?
#
# 1. `git add .` — se marcaron los conflictos como resueltos
# 2. `git commit -m "guardado"` — se confirmó el merge con commit

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **`git reset --hard origin/dev`**
#
# Ese comando hace tres cosas importantes:
#
# `git reset` — mueve el puntero de tu rama local
# `--hard —` descarta todos los cambios locales sin preguntar (staged y unstaged)
# `origin/dev` — al estado exacto en que está la rama dev en el remoto
#
# ☢️ **Es destructivo:** cualquier cambio local que no hayas pusheado se pierde para siempre.
# Se usa típicamente cuando quieres descartar todo lo local y sincronizarte completamente con el remoto.

# %% [markdown]
# # **Problema - Solución** que nos encotramos al estar trabajando en una rama incorrecta:
#
# Hemos trabajado sin querer en la rama `dev`, cuando deberíamos haberlo hecho en la rama `6-analisis-univariado`.
# Para cambiar de rama **sin perder los cambios**, desde `dev` hacemos:
#
# ```bash
# git checkout 6-analisis-univariado
# ```
#
# Esto nos lleva directamente a la rama destino. Desde ahí hacemos:
#
# ```bash
# git merge dev
# ```
#
# > Si la rama no existiese, podríamos crearla y cambiar a ella en un solo paso con `git checkout -b nombre-nueva-rama`.
